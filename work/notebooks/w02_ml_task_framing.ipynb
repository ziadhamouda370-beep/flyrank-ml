# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ziadhamouda370-beep/flyrank-ml/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# I will frame this as a classification task because the current starter target is a binary outcome: whether a content item is labeled as declining or not declining. The classification output can later be converted into a priority score and used to rank content for review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("ML task type: Classification")
print("Target: declining vs. not declining")
# Out:
# ML task type: Classification
# Target: declining vs. not declining

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*The target is whether a content item is declining or not declining. The label comes from the starter data's trend_direction field, where down is treated as declining. This is a defined proxy label rather than a future observed outcome, so the model should be described as learning the starter dataset's declining pattern, not predicting future Google performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Target column: trend_direction")
print("Positive class: down")
print("Target type: proxy label")
# Out:
# Target column: trend_direction
# Positive class: down
# Target type: proxy label

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*I will use recall as the main success metric. Recall measures how many of the declining content items are correctly identified by the model. A higher recall is useful here because missing a declining item could cause a potentially useful refresh opportunity to be overlooked. As a directional goal, I will aim for recall of at least 0.80 on the held-out evaluation data.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
target_recall = 0.80

print("Primary metric: Recall")
print("Directional target:", target_recall)
# Out:
# Primary metric: Recall
# Directional target: 0.8

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# The unit of analysis is one pseudonymized content item. Each row represents one content item with its observed search and engagement signals and its declining or not-declining label. I will use one row per content item for the classification task.

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/ziadhamouda370-beep/flyrank-ml/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

print("Unit of analysis: one pseudonymized content item")
print("Rows:", len(df))
print("Columns:", len(df.columns))
print("Target column:", "trend_direction")
# Out:
# Unit of analysis: one pseudonymized content item
# Rows: 30000
# Columns: 44
# Target column: trend_direction

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*A fixed rule would have to choose a few thresholds for signals such as clicks, impressions, CTR, and position. These signals can interact in different ways, so one simple if-statement may miss combinations of changes that indicate a declining content item. ML can learn patterns across multiple signals and produce a consistent probability that can be used for prioritization.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Why ML: multiple signals can interact in ways that are difficult to capture with one fixed rule.")
print("Signals include search performance and engagement features.")
# Out:
# Why ML: multiple signals can interact in ways that are difficult to capture with one fixed rule.
# Signals include search performance and engagement features.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
